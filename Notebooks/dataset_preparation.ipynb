# %% [markdown]
# This notebook is the dataset preprocessing part of the project

# %%
import os

# %%
def rename_files_in_folder(folder_path):
    """
    Renames files in a folder with the folder name plus their position.

    Args:
        folder_path (str): The path to the folder.
    """
    files = os.listdir(folder_path)
    for i, file in enumerate(files):
        if os.path.isfile(os.path.join(folder_path, file)):
            new_name = f"{os.path.basename(folder_path)}_{i+1}{os.path.splitext(file)[1]}"
            try:
                os.rename(os.path.join(folder_path, file), os.path.join(folder_path, new_name))
            except FileExistsError:
                print(f"Error: File '{new_name}' already exists in the folder. Skipping.")

# Example usage:
folder_to_rename = 'Dataset_getty/1989'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Acoustic'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Fearless'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Folkmore'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Lover'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Midnights'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Reputation'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Speak_Now'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/Red'
rename_files_in_folder(folder_to_rename)
folder_to_rename = 'Dataset_getty/TTPD'
rename_files_in_folder(folder_to_rename)
# Out:
# Error: File '1989_2.jpeg' already exists in the folder. Skipping.
# Error: File '1989_3.jpg' already exists in the folder. Skipping.
# Error: File '1989_4.jpg' already exists in the folder. Skipping.
# Error: File '1989_10.jpeg' already exists in the folder. Skipping.
# Error: File '1989_14.jpg' already exists in the folder. Skipping.
# Error: File '1989_15.jpeg' already exists in the folder. Skipping.
# Error: File '1989_21.jpg' already exists in the folder. Skipping.
# Error: File '1989_25.jpeg' already exists in the folder. Skipping.
# Error: File '1989_27.jpeg' already exists in the folder. Skipping.
# Error: File '1989_28.jpg' already exists in the folder. Skipping.
# Error: File '1989_40.jpeg' already exists in the folder. Skipping.
# Error: File '1989_41.jpg' already exists in the folder. Skipping.
# Error: File '1989_46.jpg' already exists in the folder. Skipping.
# Error: File '1989_47.jpeg' already exists in the folder. Skipping.
# Error: File '1989_48.jpg' already exists in the folder. Skipping.
# Error: File '1989_51.jpg' already exists in the folder. Skipping.
# Error: File '1989_56.jpg' already exists in the folder. Skipping.
# Error: File '1989_60.jpg' already exists in the folder. Skipping.
# Error: File '1989_61.jpeg' already exists in the folder. Skipping.
# Error: File '1989_62.jpg' already exists in the folder. Skipping.
# Error: File '1989_63.jpeg' already exists in the folder. Skipping.
# Error: File '1989_64.jpg' already exists in the folder. Skipping.
# Error: File '1989_66.jpg' already exists in the folder. Skipping.
# Error: File '1989_71.jpg' already exists in the folder. Skipping.
# Error: File '1989_72.jpeg' already exists in the folder. Skipping.
# Error: File '1989_73.jpeg' already exists in the folder. Skipping.
# Error: File '1989_77.jpeg' already exists in the folder. Skipping.
# Error: File '1989_80.jpeg' already exists in the folder. Skipping.
# Error: File '1989_86.jpeg' already exists in the folder. Skipping.
# Error: File '1989_92.jpg' already exists in the folder. Skipping.
# Error: File '1989_94.jpg' already exists in the folder. Skipping.
# Error: File '1989_95.jpeg' already exists in the folder. Skipping.
# Error: File '1989_96.jpeg' already exists in the folder. Skipping.
# Error: File '1989_97.jpg' already exists in the folder. Skipping.
# Error: File '1989_101.jpg' already exists in the folder. Skipping.
# Error: File '1989_105.jpeg' already exists in the folder. Skipping.
# Error: File '1989_112.jpg' already exists in the folder. Skipping.
# Error: File '1989_116.jpeg' already exists in the folder. Skipping.
# Error: File '1989_118.jpeg' already exists in the folder. Skipping.
# Error: File '1989_128.jpeg' already exists in the folder. Skipping.
# Error: File '1989_132.jpeg' already exists in the folder. Skipping.
# Error: File '1989_135.jpg' already exists in the folder. Skipping.
# Error: File '1989_139.jpg' already exists in the folder. Skipping.
# Error: File '1989_141.jpg' already exists in the folder. Skipping.
# Error: File '1989_142.jpeg' already exists in the folder. Skipping.
# Error: File '1989_144.jpg' already exists in the folder. Skipping.
# Error: File '1989_149.jpg' already exists in the folder. Skipping.
# Error: File '1989_150.jpeg' already exists in the folder. Skipping.
# Error: File '1989_156.jpeg' already exists in the folder. Skipping.
# Error: File '1989_161.jpeg' already exists in the folder. Skipping.
# Error: File '1989_165.jpg' already exists in the folder. Skipping.
# Error: File '1989_168.jpeg' already exists in the folder. Skipping.
# Error: File '1989_175.jpeg' already exists in the folder. Skipping.
# Error: File '1989_185.jpeg' already exists in the folder. Skipping.
# Error: File '1989_192.jpeg' already exists in the folder. Skipping.
# Error: File '1989_195.jpeg' already exists in the folder. Skipping.
# Error: File '1989_197.jpg' already exists in the folder. Skipping.
# Error: File '1989_202.jpeg' already exists in the folder. Skipping.
# Error: File '1989_203.jpg' already exists in the folder. Skipping.
# Error: File '1989_208.jpeg' already exists in the folder. Skipping.
# Error: File '1989_212.jpeg' already exists in the folder. Skipping.
# Error: File '1989_220.jpg' already exists in the folder. Skipping.
# Error: File '1989_247.jpeg' already exists in the folder. Skipping.
# Error: File '1989_253.jpeg' already exists in the folder. Skipping.
# Error: File '1989_258.jpeg' already exists in the folder. Skipping.
# Error: File '1989_261.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_4.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_5.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_6.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_7.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_8.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_13.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_14.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_16.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_18.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_19.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_21.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_24.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_25.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_30.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_31.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_33.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_36.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_38.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_41.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_45.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_46.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_47.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_48.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_53.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_55.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_60.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_62.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_69.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_70.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_71.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_72.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_78.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_79.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_81.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_85.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_87.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_90.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_94.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_99.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_100.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_101.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_102.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_111.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_114.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_116.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_124.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_125.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_127.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_129.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_138.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_141.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_143.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_147.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_154.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_155.jpeg' already exists in the folder. Skipping.
# Error: File 'Acoustic_156.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_162.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_164.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_168.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_176.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_181.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_197.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_198.jpg' already exists in the folder. Skipping.
# Error: File 'Acoustic_202.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_3.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_4.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_6.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_8.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_9.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_12.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_13.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_14.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_15.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_16.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_17.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_20.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_21.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_22.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_25.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_29.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_31.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_38.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_39.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_49.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_51.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_52.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_53.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_59.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_63.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_65.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_72.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_73.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_78.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_79.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_80.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_81.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_84.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_85.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_86.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_88.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_92.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_97.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_100.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_102.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_104.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_109.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_110.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_111.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_114.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_116.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_118.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_121.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_134.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_136.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_137.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_141.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_144.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_148.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_149.jpeg' already exists in the folder. Skipping.
# Error: File 'Fearless_153.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_154.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_159.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_165.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_175.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_179.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_180.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_181.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_202.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_204.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_206.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_219.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_233.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_238.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_259.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_261.jpg' already exists in the folder. Skipping.
# Error: File 'Fearless_292.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_2.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_3.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_4.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_5.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_6.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_7.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_8.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_9.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_10.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_11.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_12.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_13.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_14.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_15.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_16.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_17.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_19.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_20.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_21.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_22.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_23.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_24.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_25.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_26.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_27.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_28.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_29.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_30.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_31.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_32.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_33.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_34.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_35.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_36.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_37.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_38.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_39.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_40.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_41.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_42.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_43.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_44.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_45.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_46.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_47.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_48.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_49.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_50.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_51.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_52.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_53.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_54.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_55.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_56.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_57.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_58.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_59.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_60.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_61.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_62.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_63.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_64.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_65.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_66.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_67.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_68.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_69.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_70.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_71.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_72.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_74.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_76.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_77.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_78.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_80.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_81.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_82.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_83.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_84.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_85.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_87.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_88.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_89.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_90.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_91.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_92.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_93.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_94.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_95.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_96.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_97.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_98.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_99.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_100.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_102.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_103.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_104.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_105.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_106.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_107.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_108.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_109.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_110.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_111.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_112.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_113.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_114.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_115.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_116.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_117.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_118.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_119.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_120.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_121.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_122.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_123.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_124.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_125.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_126.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_127.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_128.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_129.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_130.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_131.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_132.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_133.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_134.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_135.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_136.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_137.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_138.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_139.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_140.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_141.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_142.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_143.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_144.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_145.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_146.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_147.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_148.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_149.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_150.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_151.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_152.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_153.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_154.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_155.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_156.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_157.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_158.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_159.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_160.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_161.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_162.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_164.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_166.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_167.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_168.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_170.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_171.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_172.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_173.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_174.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_176.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_177.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_178.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_179.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_180.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_181.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_182.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_183.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_184.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_185.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_186.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_188.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_189.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_190.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_191.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_192.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_193.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_194.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_195.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_196.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_197.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_198.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_199.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_200.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_201.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_202.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_203.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_204.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_205.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_206.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_207.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_208.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_209.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_210.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_211.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_212.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_213.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_214.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_215.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_216.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_217.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_218.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_219.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_220.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_221.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_222.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_223.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_224.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_225.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_226.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_227.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_228.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_229.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_230.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_231.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_232.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_233.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_234.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_235.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_236.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_237.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_238.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_239.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_240.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_241.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_242.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_244.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_246.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_247.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_248.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_250.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_251.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_252.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_253.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_255.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_256.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_257.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_258.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_259.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_260.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_261.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_262.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_263.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_264.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_265.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_266.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_267.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_268.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_269.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_270.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_271.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_272.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_273.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_274.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_275.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_276.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_277.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_278.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_279.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_280.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_281.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_282.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_283.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_284.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_285.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_286.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_287.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_288.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_289.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_290.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_291.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_292.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_293.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_294.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_295.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_296.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_297.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_298.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_299.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_300.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_301.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_302.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_303.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_304.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_305.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_306.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_307.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_308.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_309.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_310.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_311.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_312.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_313.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_315.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_317.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_318.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_319.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_320.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_321.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_322.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_323.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_325.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_326.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_327.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_328.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_329.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_330.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_331.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_332.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_333.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_334.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_335.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_336.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_337.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_339.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_340.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_341.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_342.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_343.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_344.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_345.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_346.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_347.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_348.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_349.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_350.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_351.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_352.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_353.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_354.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_355.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_356.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_357.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_358.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_359.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_360.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_361.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_362.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_363.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_364.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_365.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_366.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_367.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_368.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_369.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_370.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_371.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_372.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_373.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_374.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_375.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_376.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_377.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_378.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_381.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_382.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_383.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_384.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_385.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_386.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_387.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_389.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_390.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_391.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_392.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_393.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_394.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_395.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_396.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_397.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_398.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_399.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_400.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_401.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_402.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_403.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_404.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_405.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_406.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_407.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_408.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_409.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_410.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_411.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_412.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_413.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_414.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_415.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_416.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_417.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_418.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_419.jpg' already exists in the folder. Skipping.
# Error: File 'Folkmore_420.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_2.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_3.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_4.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_5.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_6.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_7.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_8.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_9.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_10.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_11.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_12.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_13.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_14.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_15.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_16.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_17.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_18.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_19.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_20.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_21.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_22.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_23.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_24.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_25.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_27.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_28.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_29.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_30.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_31.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_32.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_33.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_34.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_35.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_36.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_37.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_38.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_39.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_41.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_42.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_43.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_44.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_45.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_47.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_48.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_49.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_50.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_52.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_53.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_54.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_55.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_56.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_57.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_58.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_59.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_60.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_61.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_62.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_63.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_64.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_65.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_66.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_67.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_68.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_69.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_70.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_71.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_73.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_75.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_76.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_78.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_79.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_81.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_82.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_83.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_84.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_85.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_86.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_87.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_89.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_90.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_92.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_93.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_95.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_96.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_97.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_98.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_99.jpg' already exists in the folder. Skipping.
# Error: File 'Lover_100.jpg' already exists in the folder. Skipping.
# ...
# Error: File 'Reputation_327.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_328.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_329.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_330.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_331.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_332.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_333.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_334.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_335.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_336.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_337.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_338.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_339.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_340.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_341.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_342.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_343.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_344.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_345.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_346.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_347.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_348.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_349.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_350.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_351.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_352.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_353.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_354.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_355.jpg' already exists in the folder. Skipping.
# Error: File 'Reputation_356.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_6.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_9.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_12.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_13.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_17.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_19.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_20.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_21.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_23.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_25.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_26.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_28.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_29.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_30.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_31.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_32.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_33.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_34.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_40.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_45.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_54.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_56.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_67.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_68.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_70.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_75.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_79.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_80.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_88.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_89.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_91.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_94.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_98.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_108.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_111.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_115.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_116.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_118.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_119.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_122.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_153.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_156.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_157.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_165.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_169.jpeg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_170.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_178.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_187.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_188.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_190.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_211.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_214.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_234.jpg' already exists in the folder. Skipping.
# Error: File 'Speak_Now_244.jpg' already exists in the folder. Skipping.
# Error: File 'Red_2.jpg' already exists in the folder. Skipping.
# Error: File 'Red_4.jpg' already exists in the folder. Skipping.
# Error: File 'Red_6.jpg' already exists in the folder. Skipping.
# Error: File 'Red_10.jpg' already exists in the folder. Skipping.
# Error: File 'Red_16.jpg' already exists in the folder. Skipping.
# Error: File 'Red_18.jpg' already exists in the folder. Skipping.
# Error: File 'Red_20.jpg' already exists in the folder. Skipping.
# Error: File 'Red_22.jpg' already exists in the folder. Skipping.
# Error: File 'Red_25.jpg' already exists in the folder. Skipping.
# Error: File 'Red_28.jpg' already exists in the folder. Skipping.
# Error: File 'Red_29.jpg' already exists in the folder. Skipping.
# Error: File 'Red_30.jpeg' already exists in the folder. Skipping.
# Error: File 'Red_31.jpg' already exists in the folder. Skipping.
# Error: File 'Red_34.jpg' already exists in the folder. Skipping.
# Error: File 'Red_35.jpeg' already exists in the folder. Skipping.
# Error: File 'Red_36.jpg' already exists in the folder. Skipping.
# Error: File 'Red_38.jpg' already exists in the folder. Skipping.
# Error: File 'Red_41.jpg' already exists in the folder. Skipping.
# Error: File 'Red_43.jpg' already exists in the folder. Skipping.
# Error: File 'Red_44.jpg' already exists in the folder. Skipping.
# Error: File 'Red_47.jpg' already exists in the folder. Skipping.
# Error: File 'Red_48.jpg' already exists in the folder. Skipping.
# Error: File 'Red_50.jpg' already exists in the folder. Skipping.
# Error: File 'Red_52.jpg' already exists in the folder. Skipping.
# Error: File 'Red_54.jpg' already exists in the folder. Skipping.
# Error: File 'Red_55.jpg' already exists in the folder. Skipping.
# Error: File 'Red_58.jpg' already exists in the folder. Skipping.
# Error: File 'Red_59.jpeg' already exists in the folder. Skipping.
# Error: File 'Red_60.jpg' already exists in the folder. Skipping.
# Error: File 'Red_62.jpg' already exists in the folder. Skipping.
# Error: File 'Red_67.jpg' already exists in the folder. Skipping.
# Error: File 'Red_71.jpg' already exists in the folder. Skipping.
# Error: File 'Red_75.jpg' already exists in the folder. Skipping.
# Error: File 'Red_76.jpg' already exists in the folder. Skipping.
# Error: File 'Red_80.jpg' already exists in the folder. Skipping.
# Error: File 'Red_84.jpg' already exists in the folder. Skipping.
# Error: File 'Red_89.jpg' already exists in the folder. Skipping.
# Error: File 'Red_94.jpg' already exists in the folder. Skipping.
# Error: File 'Red_96.jpg' already exists in the folder. Skipping.
# Error: File 'Red_97.jpg' already exists in the folder. Skipping.
# Error: File 'Red_98.jpeg' already exists in the folder. Skipping.
# Error: File 'Red_99.jpg' already exists in the folder. Skipping.
# Error: File 'Red_101.jpg' already exists in the folder. Skipping.
# Error: File 'Red_103.jpg' already exists in the folder. Skipping.
# Error: File 'Red_106.jpg' already exists in the folder. Skipping.
# Error: File 'Red_110.jpg' already exists in the folder. Skipping.
# Error: File 'Red_113.jpg' already exists in the folder. Skipping.
# Error: File 'Red_115.jpg' already exists in the folder. Skipping.
# Error: File 'Red_117.jpg' already exists in the folder. Skipping.
# Error: File 'Red_120.jpg' already exists in the folder. Skipping.
# Error: File 'Red_122.jpg' already exists in the folder. Skipping.
# Error: File 'Red_125.jpg' already exists in the folder. Skipping.
# Error: File 'Red_126.jpg' already exists in the folder. Skipping.
# Error: File 'Red_128.jpg' already exists in the folder. Skipping.
# Error: File 'Red_131.jpg' already exists in the folder. Skipping.
# Error: File 'Red_132.jpg' already exists in the folder. Skipping.
# Error: File 'Red_136.jpg' already exists in the folder. Skipping.
# Error: File 'Red_141.jpg' already exists in the folder. Skipping.
# Error: File 'Red_142.jpg' already exists in the folder. Skipping.
# Error: File 'Red_145.jpg' already exists in the folder. Skipping.
# Error: File 'Red_146.jpeg' already exists in the folder. Skipping.
# Error: File 'Red_148.jpg' already exists in the folder. Skipping.
# Error: File 'Red_150.jpg' already exists in the folder. Skipping.
# Error: File 'Red_157.jpg' already exists in the folder. Skipping.
# Error: File 'Red_158.jpg' already exists in the folder. Skipping.
# Error: File 'Red_160.jpg' already exists in the folder. Skipping.
# Error: File 'Red_173.jpg' already exists in the folder. Skipping.
# Error: File 'Red_174.jpg' already exists in the folder. Skipping.
# Error: File 'Red_176.jpg' already exists in the folder. Skipping.
# Error: File 'Red_184.jpg' already exists in the folder. Skipping.
# Error: File 'Red_186.jpg' already exists in the folder. Skipping.
# Error: File 'Red_188.jpg' already exists in the folder. Skipping.
# Error: File 'Red_194.jpg' already exists in the folder. Skipping.
# Error: File 'Red_197.jpg' already exists in the folder. Skipping.
# Error: File 'Red_209.jpg' already exists in the folder. Skipping.
# Error: File 'Red_213.jpg' already exists in the folder. Skipping.
# Error: File 'Red_215.jpg' already exists in the folder. Skipping.
# Error: File 'Red_217.jpg' already exists in the folder. Skipping.
# Error: File 'Red_223.jpg' already exists in the folder. Skipping.
# Error: File 'Red_236.jpg' already exists in the folder. Skipping.
# Error: File 'Red_237.jpg' already exists in the folder. Skipping.
# Error: File 'Red_239.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_3.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_8.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_13.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_17.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_18.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_19.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_21.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_23.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_24.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_27.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_49.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_53.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_54.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_55.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_56.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_57.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_58.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_59.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_60.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_61.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_63.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_64.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_65.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_67.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_70.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_74.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_79.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_80.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_81.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_85.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_86.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_89.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_90.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_91.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_96.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_97.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_98.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_100.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_104.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_109.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_117.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_118.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_141.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_142.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_143.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_144.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_145.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_146.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_147.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_148.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_152.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_161.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_162.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_163.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_168.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_171.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_187.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_193.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_194.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_213.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_215.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_218.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_233.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_248.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_253.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_272.jpg' already exists in the folder. Skipping.
# Error: File 'TTPD_275.jpeg' already exists in the folder. Skipping.
# Error: File 'TTPD_289.jpeg' already exists in the folder. Skipping.

# %%
import os
import shutil
import random

def split_dataset(folder_path, output_path, train_split=0.8, test_split=0.1, 
                   val_split=0.1, shuffle=True):
    """
    Splits the images in the given folder into train, test, and validation sets,
    and moves them to the specified output path, ensuring no duplicate moves.

    Args:
        folder_path (str): Path to the folder containing the images.
        output_path (str): Path to the directory where the split datasets 
                          will be saved.
        train_split (float, optional): Ratio of images for training (0.0 to 1.0). 
                                     Defaults to 0.8.
        test_split (float, optional): Ratio of images for testing (0.0 to 1.0). 
                                    Defaults to 0.1.
        val_split (float, optional): Ratio of images for validation (0.0 to 1.0). 
                                    Defaults to 0.1.
        shuffle (bool, optional): Whether to shuffle the images. Defaults to True.
        shuffle_size (int, optional): Size of the shuffle buffer. Defaults to 1000.
    """

    if train_split + test_split + val_split != 1.0:
        raise ValueError("Train, test, and validation splits must add up to 1.0")

    # Create output directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)

    # Create subfolders for train, test, and validation in the output directory
    for subfolder in ["train", "test", "val"]:
        os.makedirs(os.path.join(output_path, subfolder), exist_ok=True)

    # Get list of image files in the folder
    image_files = [
        f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))
    ]

    # Shuffle the image files
    if shuffle:
        random.shuffle(image_files)

    # Calculate the number of images for each set
    num_images = len(image_files)
    num_train = int(num_images * train_split)
    num_test = int(num_images * test_split)

    # Split the image files into sets
    train_files = image_files[:num_train]
    test_files = image_files[num_train : num_train + num_test]
    val_files = image_files[num_train + num_test :]

    # Move images to corresponding subfolders, preventing duplicates
    for file_list, subfolder in zip(
        [train_files, test_files, val_files], ["train", "test", "val"]
    ):
        for image_file in file_list:
            src_path = os.path.join(folder_path, image_file)
            dest_path = os.path.join(output_path, subfolder, image_file)
            if not os.path.exists(dest_path):  # Check if file already exists
                shutil.move(src_path, dest_path)

# %%
def organize_images(directory):
  """Organizes images in a directory into subfolders based on the first word of their filenames.

  Args:
    directory: The path to the directory containing the images.
  """

  for filename in os.listdir(directory):
    if filename.endswith(('.jpg', '.jpeg', '.png', '.gif')):  # Adjust file extensions if needed
      file_path = os.path.join(directory, filename)
      folder_name = filename.split('_')[0]  # Extract the first word before "_"
      folder_path = os.path.join(directory, folder_name)

      # Create the folder if it doesn't exist
      if not os.path.exists(folder_path):
        os.makedirs(folder_path)

      # Move the image to the corresponding folder
      shutil.move(file_path, os.path.join(folder_path, filename))

# %%
output_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\"

# 1989
_1989_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\1989"
split_dataset(_1989_path, output_path) 

# Acoustic
acoustic_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Acoustic"
split_dataset(acoustic_path, output_path) 

# Fearless
fearless_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Fearless"
split_dataset(fearless_path, output_path)

# Folkmore
folkmore_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Folkmore"
split_dataset(folkmore_path, output_path)

# Lover
lover_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Lover"
split_dataset(lover_path, output_path)

# Midnights
midnights_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Midnights"
split_dataset(midnights_path, output_path)

# Red
red_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Red"
split_dataset(red_path, output_path)

# Reputation
reputation_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Reputation"
split_dataset(reputation_path, output_path)

# Speak Now
speak_now_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\Speak_Now"
split_dataset(speak_now_path, output_path)

# TTPD
ttpd_path = "C:\\Users\\Ronan\\Documents\\ML\\Taylor_Swift_Projects\\CNN\\Dataset_getty\\TTPD"
split_dataset(ttpd_path, output_path)

# %%
# Train
train_directory = "C:/Users/Ronan/Documents/ML/Taylor_Swift_Projects/CNN/train"
organize_images(train_directory)

# Val
val_directory = "C:/Users/Ronan/Documents/ML/Taylor_Swift_Projects/CNN/val"
organize_images(val_directory)

# Test
test_directory = "C:/Users/Ronan/Documents/ML/Taylor_Swift_Projects/CNN/test"
organize_images(test_directory)
